# %% [markdown]
# # Robot Sensor Data Analysis - Bonus Exercise
#
# **Objective**: Analyze real robot sensor data from a CSV file to extract meaningful insights, detect anomalies, and create visualizations.
#
# **Skills Practiced**:
# - Data manipulation with pandas
# - Statistical analysis and calculations
# - Data visualization with matplotlib and seaborn
# - Anomaly detection techniques
# - File I/O operations
# - Jupyter notebook workflows
#
# **Instructions**:
# 1. Complete each TODO section in the code cells
# 2. Run cells sequentially to build your analysis
# 3. Answer the reflection questions at the end
# 4. Export your results and visualizations
#
# ---
#
# ## Dataset Description
#
# The `robot_sensor_data.csv` file contains sensor readings from an autonomous robot over a 24-hour period:
#
# - **timestamp**: Date and time of reading
# - **battery_level**: Battery percentage (0-100)
# - **temperature**: Internal temperature (°C)
# - **ultrasonic_distance**: Distance sensor reading (meters)
# - **camera_exposure**: Camera exposure time (milliseconds)
# - **motor_current**: Motor current draw (amps)
# - **gps_latitude**: GPS latitude coordinate
# - **gps_longitude**: GPS longitude coordinate

# %% [markdown]
# ## 1. Import Required Libraries
#
# First, we'll import the necessary libraries for data analysis and visualization.

# %%
# TODO: Import the required libraries
# You'll need: pandas, matplotlib, seaborn, numpy, and datetime

# TODO: Import pandas as pd


# TODO: Import matplotlib.pyplot as plt


# TODO: Import seaborn as sns


# TODO: Import numpy as np


# TODO: Import datetime for handling timestamps


# TODO: Configure matplotlib for better plots
# Set the style to 'seaborn-v0_8' and figure size to (12, 8)



print("📚 Libraries imported successfully!")
print("Ready to analyze robot sensor data!")

# %% [markdown]
# ## 2. Load and Explore the Dataset
#
# Now we'll load the robot sensor data and explore its basic structure.

# %%
# TODO: Load the CSV file using pandas
# Hint: Use pd.read_csv() with the filename 'robot_sensor_data.csv'


# TODO: Display basic information about the dataset
print("📊 Dataset Shape:")
# Print the shape of the dataframe

print("\n📋 Column Names:")
# Print the column names as a list

# TODO: Display the first few rows
print("\n🔍 First 5 rows:")
# Use the head() method to show first 5 rows

# TODO: Display data types and missing values
print("\n📈 Data Info:")
# Use the info() method to show data types and non-null counts

# TODO: Display basic statistics
print("\n📊 Basic Statistics:")
# Use the describe() method to show statistical summary

# %% [markdown]
# ## 3. Data Cleaning and Preprocessing
#
# Clean and prepare the data for analysis by handling missing values and converting data types.

# %%
# TODO: Check for missing values
print("🔍 Missing Values Check:")
# Use isnull().sum() to count missing values in each column


# TODO: Convert timestamp column to datetime
# Use pd.to_datetime() to convert the timestamp column
# df['timestamp'] = 

# TODO: Remove any duplicate rows
duplicates_before = len(df)
# Use drop_duplicates() method to remove duplicate rows

duplicates_after = len(df)
print(f"\n🧹 Removed {duplicates_before - duplicates_after} duplicate rows")

# TODO: Handle missing values (if any)
# Get numeric columns using select_dtypes(include=[np.number])
numeric_columns = 
# Loop through numeric columns and fill missing values with median
for col in numeric_columns:
    if df[col].isnull().sum() > 0:
        # Fill missing values with median
        print(f"✅ Filled missing values in {col} with median")

# TODO: Validate data ranges for robot sensors
print("\n🔧 Data Validation:")
# Print the min and max values for battery_level, temperature, and ultrasonic_distance
print(f"Battery level range: {df['battery_level'].min():.1f}% to {df['battery_level'].max():.1f}%")


print("✅ Data cleaning completed!")

# %% [markdown]
# ## 4. Basic Statistical Analysis
#
# Calculate key statistics to understand the robot's performance and sensor patterns.

# %%
# TODO: Calculate statistical measures for key sensors

# Battery Level Analysis
# Create a dictionary with statistical measures for battery_level
# Include: mean, median, std (standard deviation), min, max
battery_stats = {
    # 'mean': ,
    # 'median': ,
    # 'std': ,
    # 'min': ,
    # 'max': 
}

print("🔋 Battery Level Statistics:")
for stat, value in battery_stats.items():
    print(f"  {stat.capitalize()}: {value:.2f}%")

# TODO: Temperature Analysis
# Create similar dictionary for temperature statistics
temp_stats = {
    # Fill in the statistical measures
}

print("\n🌡️ Temperature Statistics:")
# Loop through and print temperature statistics


# TODO: Distance Sensor Analysis
# Create statistics dictionary for ultrasonic_distance
distance_stats = {
    # Fill in the statistical measures
}

print("\n📏 Ultrasonic Distance Statistics:")
# Loop through and print distance statistics


# TODO: Motor Current Analysis  
# Create statistics dictionary for motor_current
motor_stats = {
    # Fill in the statistical measures
}

print("\n⚡ Motor Current Statistics:")
# Loop through and print motor current statistics


print("📊 Statistical analysis completed!")

# %% [markdown]
# ## 5. Data Visualization
#
# Create visualizations to understand sensor patterns and robot behavior over time.

# %%
# TODO: Create a time series plot of battery level
# Create a figure with size (15, 6)


# Plot battery level over time using timestamp on x-axis and battery_level on y-axis
# Use linewidth=2 and color='green'


# Add title, xlabel, ylabel
# Title: '🔋 Robot Battery Level Over Time'
# X-label: 'Time'  
# Y-label: 'Battery Level (%)'

# Add grid and rotate x-axis labels
# Use grid(True, alpha=0.3) and xticks(rotation=45)


# Use tight_layout() and show the plot


print("✅ Time series plot created!")

# %%
# TODO: Create histograms for sensor distributions
# Create a figure with 2x2 subplots, size (16, 12)
fig, axes = 

# TODO: Battery level histogram (axes[0, 0])
# Use 30 bins, green color, alpha=0.7, edgecolor='black'
# Title: '🔋 Battery Level Distribution'

# TODO: Temperature histogram (axes[0, 1])
# Use 30 bins, red color, alpha=0.7, edgecolor='black'
# Title: '🌡️ Temperature Distribution'

# TODO: Distance sensor histogram (axes[1, 0])
# Use 30 bins, blue color, alpha=0.7, edgecolor='black'
# Title: '📏 Distance Sensor Distribution'

# TODO: Motor current histogram (axes[1, 1])
# Use 30 bins, orange color, alpha=0.7, edgecolor='black'
# Title: '⚡ Motor Current Distribution'

# Set appropriate x and y labels for each subplot

# Use tight_layout() and show the plot


print("✅ Histograms created!")

# %%
# TODO: Create a correlation heatmap
# Create figure with size (12, 8)


# TODO: Select numeric columns for correlation
numeric_columns = ['battery_level', 'temperature', 'ultrasonic_distance', 
                  'camera_exposure', 'motor_current', 'gps_latitude', 'gps_longitude']

# TODO: Calculate correlation matrix
# Use df[numeric_columns].corr()
correlation_matrix = 

# TODO: Create heatmap using seaborn
# Use sns.heatmap() with parameters:
# - annot=True (show correlation values)
# - cmap='coolwarm' (color scheme)
# - center=0 (center colormap at 0)
# - square=True (square cells)
# - linewidths=0.5 (cell borders)
# - cbar_kws={"shrink": .8} (colorbar size)


# Add title and show plot
# Title: '🔗 Sensor Correlation Heatmap'



print("✅ Correlation heatmap created!")

# %% [markdown]
# ## 6. Anomaly Detection
#
# Identify unusual sensor readings that might indicate problems or interesting events.

# %%
# TODO: Detect anomalies using Z-score method
def detect_anomalies_zscore(data, threshold=3):
    """
    Detect anomalies using Z-score method
    
    Args:
        data: pandas Series with numeric data
        threshold: Z-score threshold (default 3)
    
    Returns:
        Boolean Series indicating anomalies
    """
    # TODO: Calculate Z-scores
    # Formula: (data - mean) / standard_deviation
    # Use np.abs() to get absolute values
    # Return comparison with threshold
    pass

# TODO: Detect battery level anomalies
battery_anomalies = detect_anomalies_zscore(df['battery_level'])
print(f"? Battery Level Anomalies: {battery_anomalies.sum()} out of {len(df)} readings")

# TODO: Detect temperature anomalies


# TODO: Detect distance sensor anomalies


# TODO: Detect motor current anomalies


print("✅ Z-score anomaly detection completed!")

# %%
# TODO: Detect anomalies using Interquartile Range (IQR) method
def detect_anomalies_iqr(data):
    """
    Detect anomalies using IQR method
    
    Args:
        data: pandas Series with numeric data
        
    Returns:
        Boolean Series indicating anomalies
    """
    # TODO: Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = 
    Q3 = 
    
    # TODO: Calculate IQR (Interquartile Range)
    IQR = 
    
    # TODO: Calculate bounds
    # Lower bound = Q1 - 1.5 * IQR
    # Upper bound = Q3 + 1.5 * IQR
    lower_bound = 
    upper_bound = 
    
    # TODO: Return boolean series for values outside bounds
    return 

print("📊 IQR Anomaly Detection Results:")

# TODO: Apply IQR method to each sensor
# Battery level IQR anomalies
battery_iqr_anomalies = 
print(f"🔋 Battery Level IQR Anomalies: {battery_iqr_anomalies.sum()}")

# TODO: Temperature IQR anomalies


# TODO: Distance sensor IQR anomalies


# TODO: Motor current IQR anomalies


print("✅ IQR anomaly detection completed!")

# %%
# TODO: Visualize anomalies with box plots
# Create 2x2 subplot figure with size (16, 12)
fig, axes = 

# TODO: Battery level box plot (axes[0, 0])
# Use boxplot() method with labels=['Battery Level']
# Set title and ylabel


# TODO: Temperature box plot (axes[0, 1])
# Use boxplot() method with labels=['Temperature']  
# Set title and ylabel


# TODO: Distance sensor box plot (axes[1, 0])
# Use boxplot() method with labels=['Distance']
# Set title and ylabel


# TODO: Motor current box plot (axes[1, 1])
# Use boxplot() method with labels=['Motor Current']
# Set title and ylabel


# Use tight_layout() and show the plot


print("✅ Box plots for anomaly visualization created!")

# %% [markdown]
# ## 7. Export Results
#
# Save the cleaned data and analysis results for future reference.

# %%
# TODO: Save cleaned data to new CSV file
# Use to_csv() method to save dataframe
# Set index=False to avoid saving row indices

print("💾 Cleaned data saved to 'robot_sensor_data_cleaned.csv'")

# TODO: Create a summary report dictionary
# Include: total_records, time_period, average values, anomaly counts
summary_report = {
    'total_records': ,
    'time_period': f"{} to {}",  # Use min() and max() of timestamp
    'avg_battery_level': ,
    'avg_temperature': ,
    'avg_distance': ,
    'avg_motor_current': ,
    'battery_anomalies': ,  # Use .sum() on anomaly boolean series
    'temp_anomalies': ,
    'distance_anomalies': ,
    'motor_anomalies': 
}

# TODO: Save summary report to JSON
# Import json module and use json.dump()
import json


print("📊 Analysis summary saved to 'analysis_summary.json'")

# TODO: Save one of the plots as an image
# Create a new battery level timeline plot


# Save using plt.savefig() with parameters:
# - filename: 'battery_level_timeline.png'
# - dpi=300 (high resolution)
# - bbox_inches='tight' (tight cropping)


print("🖼️ Battery timeline plot saved to 'battery_level_timeline.png'")

print("✅ All results exported successfully!")

# %% [markdown]
# ## 🤖 Reflection Questions
#
# After completing your analysis, answer these questions:
#
# 1. **Battery Performance**: What patterns do you notice in the robot's battery usage? Are there any concerning trends?
#
# 2. **Temperature Management**: How does the robot's internal temperature vary? Are there any dangerous temperature spikes?
#
# 3. **Sensor Correlations**: Which sensors show the strongest correlations? What might this tell us about robot behavior?
#
# 4. **Anomaly Patterns**: What types of anomalies did you discover? Could these indicate specific robot malfunctions or environmental challenges?
#
# 5. **Operational Insights**: Based on your analysis, what recommendations would you make for improving robot performance?
#
# ---
#
# ## 🎯 Extension Challenges
#
# If you finish early, try these advanced challenges:
#
# 1. **Time-based Analysis**: Group data by hour/day and analyze patterns over different time periods
# 2. **GPS Tracking**: Plot the robot's path using latitude/longitude coordinates
# 3. **Predictive Analysis**: Use battery drain patterns to predict when the robot will need charging
# 4. **Custom Visualizations**: Create interactive plots using plotly instead of matplotlib
# 5. **Machine Learning**: Implement a simple clustering algorithm to group similar sensor readings
#
# ---
#
# ## 📚 What You've Learned
#
# - **Data Loading**: Reading CSV files with pandas
# - **Data Cleaning**: Handling missing values and data validation
# - **Statistical Analysis**: Calculating means, medians, and standard deviations
# - **Data Visualization**: Creating histograms, time series, correlation heatmaps
# - **Anomaly Detection**: Using Z-score and IQR methods
# - **File I/O**: Exporting cleaned data and analysis results
# - **Jupyter Workflows**: Interactive data science techniques
#
# **Congratulations!** 🎉 You've completed a comprehensive data analysis of robot sensor data!
